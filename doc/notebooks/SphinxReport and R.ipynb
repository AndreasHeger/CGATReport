# %%
import os
os.chdir('/ifs/devel/sphinx-report/doc')
import SphinxReport.test
args = "-r none -t MeltedExpressionLevels -o statement=aes(expression, color=track) + geom_density() + facet_grid( function ~ .)".split(" ")
result = SphinxReport.test.main( args )
# %load_ext rmagic
# Out:
# ----------------------------------------
# data is available in the 'result' object
# ----------------------------------------
# pushed 'all' to R
# ----------------------------------------
# ----------------------------------------
# data is available in the 'result' object
# ----------------------------------------
# pushed 'all' to R
# ----------------------------------------
# The rmagic extension is already loaded. To reload it, use:
#   %reload_ext rmagic

# %%
# %R all
# Out:
# array([['experiment1', 'experiment1', 'experiment1', ..., 'experiment2',
#         'experiment2', 'experiment2'],
#        ['gene 0', 'gene 1', 'gene 2', ..., 'gene197', 'gene198', 'gene199'],
#        ['housekeeping', 'regulation', 'housekeeping', ..., 'regulation',
#         'housekeeping', 'regulation'],
#        ['38.641072', '18.227837', '40.163367', ..., '4.445704',
#         '40.955454', '7.20196']],
#       dtype='|S12')

# %%
# %R g = ggplot( all, aes(expression, color=track))+ geom_density() + facet_grid( function ~ .)
# %R g 
# %R plot(g)
# Out:
# Error while parsing the string.
# array([<rpy2.rinterface.SexpVector - Python:0x73c0378 / R:0x809b728>,
#        <rpy2.rinterface.SexpVector - Python:0x73c0390 / R:0x7a6e5e0>,
#        <rpy2.rinterface.SexpVector - Python:0x73c03a8 / R:0x777fec0>], dtype=object)
